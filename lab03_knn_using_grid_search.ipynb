# %% [markdown]
# <a href="https://colab.research.google.com/github/Pimwipha302004/Pimwipha302004-Pimwipha-229352-StatisticalLeaening-2/blob/main/lab03_knn_using_grid_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Statistical Learning for Data Science 2 (229352)
# #### Instructor: Donlapark Ponnoprat
#
# #### [Course website](https://donlapark.pages.dev/229352/)
#
# ## Lab #3

# %%
from sklearn.datasets import fetch_20newsgroups

train = fetch_20newsgroups(subset='train')
test = fetch_20newsgroups(subset='test')

Xtrain = train.data[:3000]
ytrain = train.target[:3000]
Xtest = test.data[:500]
ytest = test.target[:500]

print("X:", len(Xtest))
print("y:", len(ytest))
# Out:
# X: 500
# y: 500

# %%
print("X[0]:", Xtrain[0])
print("y[0]:", ytrain[0])
# Out:
# X[0]: From: lerxst@wam.umd.edu (where's my thing)
# Subject: WHAT car is this!?
# Nntp-Posting-Host: rac3.wam.umd.edu
# Organization: University of Maryland, College Park
# Lines: 15
#
#  I was wondering if anyone out there could enlighten me on this car I saw
# the other day. It was a 2-door sports car, looked to be from the late 60s/
# early 70s. It was called a Bricklin. The doors were really small. In addition,
# the front bumper was separate from the rest of the body. This is
# all I know. If anyone can tellme a model name, engine specs, years
# of production, where this car is made, history, or whatever info you
# have on this funky looking car, please e-mail.
#
# Thanks,
# - IL
#    ---- brought to you by your neighborhood Lerxst ----
#
#
#
#
#
# y[0]: 7

# %%
train.target_names
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %% [markdown]
# ### Apply Tfidf ([documentation](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# define transformation
tfidf = TfidfVectorizer(stop_words='english')

# fit+transform training set
Xtrain_tfidf = tfidf.fit_transform(Xtrain)

# See output
Xtrain_tfidf
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 341881 stored elements and shape (3000, 61689)>

# %%
#tfidf.vocabulary_

# %% [markdown]
# #### Exercise 1: Find post in the training set that is closest in tf-idf to the first post in the test set (`Xtest[0]`). Print the content of both posts (not the tf-idf vectors).

# %% [markdown]
# ### Classify with k-Nearest Neighbor (kNN) ([documentation](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html))

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Transform the first test post
test0_tfidf = tfidf.transform([Xtest[0]])

# compute cosine similarity
similarities = cosine_similarity(test0_tfidf, Xtrain_tfidf)[0]

# find the most similar document
closest_index = np.argmax(similarities)

print("===== TEST POST =====")
print(Xtest[0])
print("\n===== MOST SIMILAR TRAINING POST =====")
print(Xtrain[closest_index])
# Out:
# ===== TEST POST =====
# From: v064mb9k@ubvmsd.cc.buffalo.edu (NEIL B. GANDLER)
# Subject: Need info on 88-89 Bonneville
# Organization: University at Buffalo
# Lines: 10
# News-Software: VAX/VMS VNEWS 1.41
# Nntp-Posting-Host: ubvmsd.cc.buffalo.edu
#
#
#  I am a little confused on all of the models of the 88-89 bonnevilles.
# I have heard of the LE SE LSE SSE SSEI. Could someone tell me the
# differences are far as features or performance. I am also curious to
# know what the book value is for prefereably the 89 model. And how much
# less than book value can you usually get them for. In other words how
# much are they in demand this time of year. I have heard that the mid-spring
# early summer is the best time to buy.
#
# 			Neil Gandler
#
#
# ===== MOST SIMILAR TRAINING POST =====
# From: v063kcbp@ubvmsd.cc.buffalo.edu (MITCH)
# Subject: Thanks! (Backing Up Masters)
# Keywords: Misled, Confused, Advice, Comprendo!
# Organization: University at Buffalo
# Lines: 8
# News-Software: VAX/VMS VNEWS 1.41
# Nntp-Posting-Host: ubvmsd.cc.buffalo.edu
#
#
# 	Just a quick THANKS to the many who explained the backing up of my
# masters.  Apparently they are NOT copy-protected; I just used a program that
# is unable to handle high-density (old shit).  I was surprised to hear that
# "NO programs on high-density disks have copy protection," which someone
# back there said.  Huh!  Learn something new every day!
#
# 						- Mitch

# %%
from sklearn.neighbors import KNeighborsClassifier

# Define model
nb = KNeighborsClassifier(n_neighbors=5)

# Fit the model
nb.fit(Xtrain_tfidf, ytrain)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# Evaluate on the test set using [`classification_report`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html)
#
# We will focus on the [F1-score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html)

# %%
from sklearn.metrics import classification_report

# Transform the test set
Xtest_tfidf = tfidf.transform(Xtest)

# Make predictions on the test set
ypred = nb.predict(Xtest_tfidf)

#report classification scores
print(classification_report(ytest, ypred, target_names=train.target_names))
# Out:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.35      0.43      0.38        21
#            comp.graphics       0.33      0.48      0.39        21
#  comp.os.ms-windows.misc       0.46      0.62      0.52        26
# comp.sys.ibm.pc.hardware       0.45      0.56      0.50        34
#    comp.sys.mac.hardware       0.62      0.47      0.53        34
#           comp.windows.x       0.88      0.54      0.67        26
#             misc.forsale       0.35      0.55      0.43        22
#                rec.autos       0.53      0.57      0.55        28
#          rec.motorcycles       0.80      0.73      0.76        33
#       rec.sport.baseball       0.77      0.68      0.72        25
#         rec.sport.hockey       0.67      0.74      0.70        27
#                sci.crypt       0.76      0.95      0.84        20
#          sci.electronics       0.36      0.21      0.26        24
#                  sci.med       0.78      0.61      0.68        23
#                sci.space       0.84      0.75      0.79        28
#   soc.religion.christian       0.62      0.62      0.62        29
#       talk.politics.guns       0.56      0.71      0.62        21
#    talk.politics.mideast       0.82      0.78      0.80        18
#       talk.politics.misc       0.75      0.46      0.57        26
#       talk.religion.misc       0.25      0.14      0.18        14
#
#                 accuracy                           0.59       500
#                macro avg       0.60      0.58      0.58       500
#             weighted avg       0.61      0.59      0.59       500

# %% [markdown]
# ### Combine all methods into a [pipeline](https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html)

# %%
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(stop_words='english')),
    ('nb', KNeighborsClassifier(n_neighbors=5))
])

# Fit the pipeline to the training set
pipeline.fit(Xtrain, ytrain)

# Make predictions on the test set
ypred2 = pipeline.predict(Xtest)

# report classification scores
print(classification_report(ytest, ypred2, target_names=train.target_names))
# Out:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.35      0.43      0.38        21
#            comp.graphics       0.33      0.48      0.39        21
#  comp.os.ms-windows.misc       0.46      0.62      0.52        26
# comp.sys.ibm.pc.hardware       0.45      0.56      0.50        34
#    comp.sys.mac.hardware       0.62      0.47      0.53        34
#           comp.windows.x       0.88      0.54      0.67        26
#             misc.forsale       0.35      0.55      0.43        22
#                rec.autos       0.53      0.57      0.55        28
#          rec.motorcycles       0.80      0.73      0.76        33
#       rec.sport.baseball       0.77      0.68      0.72        25
#         rec.sport.hockey       0.67      0.74      0.70        27
#                sci.crypt       0.76      0.95      0.84        20
#          sci.electronics       0.36      0.21      0.26        24
#                  sci.med       0.78      0.61      0.68        23
#                sci.space       0.84      0.75      0.79        28
#   soc.religion.christian       0.62      0.62      0.62        29
#       talk.politics.guns       0.56      0.71      0.62        21
#    talk.politics.mideast       0.82      0.78      0.80        18
#       talk.politics.misc       0.75      0.46      0.57        26
#       talk.religion.misc       0.25      0.14      0.18        14
#
#                 accuracy                           0.59       500
#                macro avg       0.60      0.58      0.58       500
#             weighted avg       0.61      0.59      0.59       500

# %% [markdown]
# Now we will use [grid search cross-validation](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html) to find model with the best hyperparameters

# %% [markdown]
# ![5CV](https://scikit-learn.org/stable/_images/grid_search_cross_validation.png)

# %%
from sklearn.model_selection import GridSearchCV

# Parameter grid ที่เราจะลองปรับ
params = {
    'tfidf__min_df': [1, 2, 5],
    'tfidf__max_df': [0.8, 0.9, 1.0],
    'nb__n_neighbors': [3, 5, 7, 9]
}

# Define GridSearchCV
gridcv = GridSearchCV(
    pipeline,
    params,
    scoring='f1_macro',
    cv=3
)

# Fit and cross-validate the model on 3-fold data
gridcv.fit(Xtrain, ytrain)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('tfidf',
#                                         TfidfVectorizer(stop_words='english')),
#                                        ('nb', KNeighborsClassifier())]),
#              param_grid={'nb__n_neighbors': [3, 5, 7, 9],
#                          'tfidf__max_df': [0.8, 0.9, 1.0],
#                          'tfidf__min_df': [1, 2, 5]},
#              scoring='f1_macro')

# %%
gridcv.best_estimator_
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer(max_df=0.8, stop_words='english')),
#                 ('nb', KNeighborsClassifier(n_neighbors=9))])

# %%
# Make predictions on the test set
ypred3 = gridcv.predict(Xtest)

# Report classification scores
print(classification_report(ytest, ypred3, target_names=train.target_names))
# Out:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.47      0.43      0.45        21
#            comp.graphics       0.39      0.52      0.45        21
#  comp.os.ms-windows.misc       0.47      0.54      0.50        26
# comp.sys.ibm.pc.hardware       0.44      0.53      0.48        34
#    comp.sys.mac.hardware       0.60      0.62      0.61        34
#           comp.windows.x       0.71      0.65      0.68        26
#             misc.forsale       0.42      0.50      0.46        22
#                rec.autos       0.66      0.68      0.67        28
#          rec.motorcycles       0.69      0.73      0.71        33
#       rec.sport.baseball       0.78      0.72      0.75        25
#         rec.sport.hockey       0.62      0.78      0.69        27
#                sci.crypt       0.81      0.85      0.83        20
#          sci.electronics       0.62      0.21      0.31        24
#                  sci.med       0.79      0.65      0.71        23
#                sci.space       0.75      0.75      0.75        28
#   soc.religion.christian       0.62      0.69      0.66        29
#       talk.politics.guns       0.52      0.76      0.62        21
#    talk.politics.mideast       0.81      0.72      0.76        18
#       talk.politics.misc       0.81      0.50      0.62        26
#       talk.religion.misc       0.40      0.14      0.21        14
#
#                 accuracy                           0.61       500
#                macro avg       0.62      0.60      0.60       500
#             weighted avg       0.62      0.61      0.60       500

# %% [markdown]
# #### Exercise 2:
#
# 1. Use grid search 5-fold cross-validation across different values of the following two kNN parameters: `n_neighbors` and `metric`  **on the training set** to find the best model.
#
# 2. For the best value of `n_neighbors` and `metric` you found above, compute the `f1_macro` score **on the test set**.
# * Print the value of `n_neighbors` and `metric`.
# * Print the model's `f1_macro` score.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer

# Define pipeline
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(stop_words='english')),
    ('nb', KNeighborsClassifier())
])

# Parameter grid
params = {
    'nb__n_neighbors': [1, 3, 5, 7, 9, 11],
    'nb__metric': ['euclidean', 'manhattan', 'cosine']
}

# Grid search 5-fold CV
gridcv = GridSearchCV(
    pipeline,
    params,
    scoring='f1_macro',
    cv=5,
    n_jobs=-1
)

# Fit on training set
gridcv.fit(Xtrain, ytrain)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('tfidf',
#                                         TfidfVectorizer(stop_words='english')),
#                                        ('nb', KNeighborsClassifier())]),
#              n_jobs=-1,
#              param_grid={'nb__metric': ['euclidean', 'manhattan', 'cosine'],
#                          'nb__n_neighbors': [1, 3, 5, 7, 9, 11]},
#              scoring='f1_macro')

# %%
#2.
from sklearn.metrics import f1_score

# Predict using the best model found above
ypred_ex2 = gridcv.predict(Xtest)

# Compute f1_macro
f1 = f1_score(ytest, ypred_ex2, average='macro')

# %%
#Print the value of n_neighbors and metric.
print("Best n_neighbors:", gridcv.best_params_['nb__n_neighbors'])
print("Best metric:", gridcv.best_params_['nb__metric'])
# Out:
# Best n_neighbors: 11
# Best metric: euclidean

# %%
#Print the model's f1_macro score.
print("F1-macro score on test set:", f1)
# Out:
# F1-macro score on test set: 0.6044157505029957
